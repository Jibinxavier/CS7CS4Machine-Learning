# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold
import pandas as pd
from helper import *
pd.options.display.max_columns = None

from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## Import DataSet

# %%
sumdata_url = "https://www.dropbox.com/sh/euppz607r6gsen2/AABABUTdx7YqCeBquA1Ky7z8a/The%20SUM%20dataset?dl=1#"
housing_price_url = "https://www.dropbox.com/sh/euppz607r6gsen2/AAAVLZzU4E7ro0BiRzPG3pP8a/House%20Prices?dl=1"
census_data_url = "https://www.dropbox.com/sh/euppz607r6gsen2/AADfweTUjMlkayMQ6JvKUOGia/Census-Income%20(KDD)%20Data%20Set?dl=0"
all_urls = [sumdata_url, housing_price_url, census_data_url]

# %%
get_data(all_urls) # retrieves the data if there is no data folder

# %%
sumdata_noise_path = "data/with noise/The SUM dataset, with noise.csv"
sumdata_path = "data/without noise/The SUM dataset, without noise.csv"
housing_price_path = "data/housing dataset.csv" # has more than 30 features
census_path = "data/housing dataset.csv"
titanic_path = "data/"
# need one more
# what a brilliant idea to name files with space

# %% [markdown]
# ## Load datasets sum_noise

# %%
sumdata_noise = pd.read_csv(sumdata_noise_path, delimiter=";")
sumdata_noise
# Out:
#         Instance  Feature 1  Feature 2  Feature 3  Feature 4  \
# 0              1      66957      74432      96087     103120
# 1              2      96030      86875     108299     148025
# 2              3      26212      23398      27668      39678
# 3              4      28363      33381      42447      35270
# 4              5      38960      50255      79879      91885
# 5              6      34616      45307      50710      58657
# 6              7      12888      20126      22753      23219
# 7              8      30922      38291      43157      53434
# 8              9      33869      47235      53800      69464
# 9             10      28247      24863      41941      38753
# 10            11      11533      15105      15618      20434
# 11            12     100336     136636     123603     190534
# 12            13      14904      21058      22569      28412
# 13            14      37161      40892      53308      51163
# 14            15      37394      53690      61280      73309
# 15            16      31363      32102      54582      51201
# 16            17      38577      49221      60327      72657
# 17            18      61255      79958      85804     105528
# 18            19      69378     102553     122961     121382
# 19            20      92869      96203     124016     165965
# 20            21      74146      65371      79886     104850
# 21            22      17373      22042      25303      34805
# 22            23      45353      69765      69150      78718
# 23            24      85805     102966     130912     168282
# 24            25      24672      28461      38071      42469
# 25            26      25440      30591      40500      43105
# 26            27      66846      86768      93007     130986
# 27            28      75965     107280     134577     125135
# 28            29      51466      75398      98385     117070
# 29            30       7117       8618      12699      16359
# ...          ...        ...        ...        ...        ...
# 968105    968106      51398      71774      69898      86394
# 968106    968107       8615       8377      14140      12690
# 968107    968108      70454     110653     104621     125953
# 968108    968109     110177     117559     135701     176211
# 968109    968110      41150      62812      61559      69970
# 968110    968111       5432       5150       7967       7358
# 968111    968112      60792      82682      97070     108411
# 968112    968113      27706      24287      32547      45357
# 968113    968114      32738      43185      49026      68009
# 968114    968115      32860      48010      46921      53573
# 968115    968116      81669      98688     153968     161048
# 968116    968117      39588      38235      46932      49788
# 968117    968118      59206      94438      99195     130376
# 968118    968119      87340     107978     148458     135501
# 968119    968120      12519      19407      23519      26361
# 968120    968121      85601     111403     144856     175032
# 968130                    94038      85051      92022     133716     161423
# 968131                    82524     231169     256591     322962     482390
# 968132                    27492     165979     199364     260573     316229
# 968133                   110958     204188     256786     271030     356286
# 968134                    86172      49452      63203      57445      64963
#
#         Feature 10  Noisy Target Noisy Target Class
# 0           304071       1434819  Very Large Number
# 1           543092       2148748  Very Large Number
# 2           115418        476405  Very Large Number
# 3           147368        635169  Very Large Number
# 4           250659       1221471  Very Large Number
# 5           210654        794117  Very Large Number
# 6            78915        363026       Large Number
# 7           160433        813129  Very Large Number
# 8           151482        914668  Very Large Number
# 9           149352        696654  Very Large Number
# 10           77612        294332       Large Number
# 11          432851       2402404  Very Large Number
# 12           79792        364763       Large Number
# 13          199063        928546  Very Large Number
# 14          186853        934416  Very Large Number
# 15          166554        661380  Very Large Number
# 16          187250        878693  Very Large Number
# 17          346678       1476512  Very Large Number
# 18          333046       1757702  Very Large Number
# 19          440788       2324356  Very Large Number
# 20          385674       1692158  Very Large Number
# 21          110461        448393       Large Number
# 22          299978       1194774  Very Large Number
# 23          499661       2349884  Very Large Number
# 24          118317        518079       Large Number
# 25          159106        647403  Very Large Number
# 26          392248       1749426  Very Large Number
# 27          374522       1800215  Very Large Number
# 28          275767       1384235  Very Large Number
# 29           45751        206832       Large Number
# ...            ...           ...                ...
# 968105      264927       1209543  Very Large Number
# 968106       48876        218506       Large Number
# 968107      344483       1862465  Very Large Number
# 968108      549248       2340351  Very Large Number
# 968109      231498       1135878  Very Large Number
# 968110       26040        118905       Large Number
# 968111      280197       1332697  Very Large Number
# 968112      119479        594709  Very Large Number
# 968113      214322        923964  Very Large Number
# 968114      146670        717601  Very Large Number
# 968115      583161       2347042  Very Large Number
# 968116      141991        792496  Very Large Number
# 968117      379038       1667755  Very Large Number
# 968118      504225       2352591  Very Large Number
# 968119       86676        403987  Very Large Number
# 968120      386359       2049657  Very Large Number
# 968121      541491       2062729  Very Large Number
# 968122       89070        386784       Large Number
# 968123      589716       2318935  Very Large Number
# 968124       67940        271587       Large Number
# 968125      158775        710252  Very Large Number
# 968126      479204       2108635  Very Large Number
# 968127      397061       1849798  Very Large Number
# 968128       43029        255433       Large Number
# 968129       61879        318092       Large Number
# 968130      178481        905094  Very Large Number
# 968131      568523       2255327  Very Large Number
# 968132      315738       1688070  Very Large Number
# 968133      314259       1734467  Very Large Number
# 968134       79099        455250       Large Number
#
# [968135 rows x 13 columns]

# %% [markdown]
# ## Preprocess sum_noise dataset
#
# - Remove 'Instance' as it simply represents the row number
# - Extract 'Nosiy Target' as regression target
# - Extract 'Nosiy Class' as classification target
# - Extract rest columns as explananatory variables
# - Apply Feature Scaling to the dataset
#
# - Ensure all dataframe has been converted to numpy array

# %%
# Remove 'Instance' as it simply represents the row number
sumdata_noise.drop('Instance', axis = 1)

# Use 'Nosiy Target' as regression target
sumdata_noise_reg_Y = sumdata_noise['Noisy Target'].values.reshape(-1, 1)

# Use 'Nosiy Target Class' as regression target
sumdata_noise_classif_Y = sumdata_noise['Noisy Target Class']

# Use rest columns as explananatory variables
sumdata_noise_X = sumdata_noise.iloc[:, 0:-2]

# Apply Feature Scaling to the dataset 
from sklearn.preprocessing import StandardScaler
scX = StandardScaler()
scY = StandardScaler()
sumdata_noise_X = scX.fit_transform(sumdata_noise_X)
sumdata_noise_reg_Y = scY.fit_transform(sumdata_noise_reg_Y)

sumdata_noise_X
# Out:
# /Users/kiyim/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:444: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# array([[-1.73204902,  0.57148372,  0.40463575, ...,  0.01029815,
#          0.01473561,  0.29953474],
#        [-1.73204544,  1.55295829,  0.75447754, ...,  0.8441455 ,
#          1.48881339,  1.86218921],
#        [-1.73204186, -0.80402556, -1.03021326, ..., -1.04344437,
#         -1.04000593, -0.93382741],
#        ...,
#        [ 1.73204186,  0.03042869,  0.34654902, ...,  0.76615191,
#          0.79476291,  0.37581042],
#        [ 1.73204544,  0.73163628,  0.32251022, ...,  0.86467558,
#          1.10936719,  0.36614112],
#        [ 1.73204902, -0.98058498, -1.05430829, ..., -1.14767765,
#         -1.17865895, -1.17127118]])

# %% [markdown]
# ## Load datasets sumdata

# %%
sumdata = pd.read_csv(sumdata_path, delimiter=";")
sumdata.head(n=500)
# Out:
#      Instance  Feature 1  Feature 2  Feature 3  Feature 4  \
# 0           1      57326      68791      82549      99059
# 1           2      87859     105431     126517     151820
# 2           3      23721      28465      34158      40990
# 3           4      24771      29725      35670      42804
# 4           5      47862      57434      68921      82705
# 5           6      35286      42343      50812      60974
# 6           7      14070      16884      20261      24313
# 7           8      34018      40822      48986      58783
# 8           9      36379      43655      52386      62863
# 9          10      25867      31040      37248      44698
# 10         11      12715      15258      18310      21972
# 11         12      97319     116783     140140     168168
# 12         13      16026      19231      23077      27692
# 13         14      35459      42551      51061      61273
# 14         15      43736      52483      62980      75576
# 15         16      32704      39245      47094      56513
# 16         17      38120      45744      54893      65872
# 17         18      61811      74173      89008     106810
# 18         19      72119      86543     103852     124622
# 19         20      99219     119063     142876     171451
# 20         21      66678      80014      96017     115220
# 21         22      18097      21716      26059      31271
# 22         23      50336      60403      72484      86981
# 23         24      91185     109422     131306     157567
# 24         25      23861      28633      34360      41232
# 25         26      26066      31279      37535      45042
# 26         27      72817      87380     104856     125827
# 27         28      84499     101399     121679     146015
# 28         29      63853      76624      91949     110339
# 29         30       8106       9727      11672      14006
# ..        ...        ...        ...        ...        ...
# 470       471      29813      35776      42931      51517
# 471       472      43499      52199      62639      75167
# 472       473      87699     105239     126287     151544
# 473       474      69972      83966     100759     120911
# 474       475      42347      50816      60979      73175
# 475       476      11973      14368      17242      20690
# 476       477      14798      17758      21310      25572
# 477       478      80161      96193     115432     138518
# 478       479      27252      32702      39242      47090
# 479       480       1805       2166       2599       3119
# 480       481       2418       2902       3482       4178
# 481       482       2374       2849       3419       4103
# 494                    51888     139967     167960     201552     241862
# 495                    79952     227405     272886     327463     392956
# 496                    95391     113182     135818     162982     195578
# 497                    67908     157610     189132     226958     272350
# 498                     4960      17676      21211      25453      30544
# 499                    37457     133573     160288     192346     230815
#
#      Feature 10   Target       Target Class
# 0        295789  1073444  Very Large Number
# 1        453332  1645184  Very Large Number
# 2        122395   444184       Large Number
# 3        127813   463844       Large Number
# 4        246955   896224  Very Large Number
# 5        182069   660743  Very Large Number
# 6         72599   263467       Large Number
# 7        175528   637002  Very Large Number
# 8        187710   681213  Very Large Number
# 9        133469   484369       Large Number
# 10        65606   238093       Large Number
# 11       502147  1822335  Very Large Number
# 12        82686   300079       Large Number
# 13       182962   663984  Very Large Number
# 14       225668   818970  Very Large Number
# 15       168748   612399  Very Large Number
# 16       196691   713810  Very Large Number
# 17       318931  1157431  Very Large Number
# 18       372118  1350450  Very Large Number
# 19       511949  1857909  Very Large Number
# 20       344045  1248570  Very Large Number
# 21        93374   338864       Large Number
# 22       259721   942554  Very Large Number
# 23       470491  1707457  Very Large Number
# 24       123119   446807       Large Number
# 25       134494   488090       Large Number
# 26       375716  1363509  Very Large Number
# 27       435998  1582277  Very Large Number
# 28       329471  1195677  Very Large Number
# 29        41820   151773       Large Number
# ..          ...      ...                ...
# 470      153828   558257  Very Large Number
# 471      224447   814537  Very Large Number
# 472      452510  1642197  Very Large Number
# 473      361038  1310240  Very Large Number
# 474      218498   792952  Very Large Number
# 475       61782   224209       Large Number
# 476       76357   277106       Large Number
# 477      413612  1501037  Very Large Number
# 478      140610   510289  Very Large Number
# 479        9314    33801      Medium Number
# 480       12476    45278      Medium Number
# 481       12253    44465      Medium Number
# 482      130085   472089       Large Number
# 483      372232  1350862  Very Large Number
# 484       40358   146465       Large Number
# 485      216605   786076  Very Large Number
# 486      265807   964636  Very Large Number
# 487       39730   144184       Large Number
# 488      100801   365817       Large Number
# 489      158732   576053  Very Large Number
# 490      492794  1788395  Very Large Number
# 491      462965  1680140  Very Large Number
# 492      244925   888855  Very Large Number
# 493      326572  1185157  Very Large Number
# 494      290234  1053287  Very Large Number
# 495      471547  1711286  Very Large Number
# 496      234694   851723  Very Large Number
# 497      326820  1186060  Very Large Number
# 498       36653   133015       Large Number
# 499      276978  1005176  Very Large Number
#
# [500 rows x 13 columns]

# %% [markdown]
# ## Preprocess sumdata dataset
#
# - Remove 'Instance' as it simply represents the row number
# - Extract 'Nosiy Target' as regression target
# - Extract 'Nosiy Class' as classification target
# - Extract rest of the columns as explananatory variables
# - Apply Feature Scaling to the dataset
#
# - Ensure all dataframe has been converted to numpy array

# %%
# Remove 'Instance' as it simply represents the row number
sumdata.drop('Instance', axis = 1)

# Use 'Nosiy Target' as regression target
sumdata_reg_Y = sumdata['Target'].values.reshape(-1, 1)

# Use 'Nosiy Target Class' as classification target
sumdata_classif_Y = sumdata['Target Class']

# Use rest columns as explananatory variables
sumdata_X = sumdata.iloc[:, 0:-2].values
# Apply Feature Scaling to the dataset 
from sklearn.preprocessing import StandardScaler
scX = StandardScaler()
scY = StandardScaler()
sumdata_X = scX.fit_transform(sumdata_X)
sumdata_reg_Y = scY.fit_transform(sumdata_reg_Y)
sumdata_X.head(n=500)
# Out:
# /Users/kiyim/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:444: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-102-88d0f7c9bdd6> in <module>()
#      16 sumdata_X = scX.fit_transform(sumdata_X)
#      17 sumdata_reg_Y = scY.fit_transform(sumdata_reg_Y)
# ---> 18 sumdata_X.head(n=500)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'head'

# %% [markdown]
# ## Load housing price dataset

# %%
housing_price = pd.read_csv(housing_price_path)
housing_price = housing_price
housing_price

# %% [markdown]
# ## Preprocess housing price dataset
#
# - Remove 'Id' as it simply represents the row number
# - Use 'SalePrice' as regression target
# - Use 'SaleCondition' as classification target
# - For explananatory variables, use the following numerical variable and categorical variables
#     - Numerical
#         - GarageArea
#         - GarageCars
#         - LotArea
#         - YearBuilt
#         - 1stFlrSF
#         - 2ndFlrSF
#     - Categorical
#         - Neighborhood, as the career of the neighbour impacts on factors such as the consuming power of the area
#         - HouseStyle, well-designed house is more expensive
# - Apply Feature Scaling to the dataset
#
# - Ensure all dataframe has been converted to numpy array

# %%
# Remove 'Instance' as it simply represents the row number
housing_price.drop('Id', axis = 1)

## filter unused categorical columns and drop NaN, we only want to keep 'neighborhood' and 'housestyle' 
## in our explanantory vairbale

# get all the numerical data
filtered_table = housing_price['GarageArea']
filtered_table = pd.concat([filtered_table, housing_price['GarageCars']], axis=1)
filtered_table = pd.concat([filtered_table, housing_price['LotArea']], axis=1)
filtered_table = pd.concat([filtered_table, housing_price['YearBuilt']], axis=1)
filtered_table = pd.concat([filtered_table, housing_price['1stFlrSF']], axis=1)
filtered_table = pd.concat([filtered_table, housing_price['2ndFlrSF']], axis=1)
filtered_table

# get the two categorical variable that we wants to use
filtered_table = pd.concat([filtered_table, pd.get_dummies(housing_price['Neighborhood']).iloc[:, :-1]], axis=1)
filtered_table = pd.concat([filtered_table, pd.get_dummies(housing_price['HouseStyle']).iloc[:, :-1]], axis=1)

# get the regression target and classification target
filtered_table = pd.concat([filtered_table, housing_price['SalePrice']], axis=1)
filtered_table = pd.concat([filtered_table, housing_price['SaleCondition']], axis=1)

# drop NaN
filtered_table = filtered_table.dropna()

# Use 'Nosiy Target' as regression target
housing_price_reg_Y = filtered_table['SalePrice'].reshape(-1, 1)

# Use 'Nosiy Target Class' as classification target
housing_price_classif_Y = filtered_table['SaleCondition'].reshape(-1, 1)

# Get other columns as the explanatory variables
filtered_table = filtered_table.drop('SalePrice', 1)
housing_price_X = filtered_table.drop('SaleCondition', 1)
housing_price_X

# Apply Feature Scaling to the numeric variables and regression target 
scX = StandardScaler()
scY = StandardScaler()
housing_price_X = scX.fit_transform(housing_price_X)
housing_price_reg_Y = scY.fit_transform(housing_price_reg_Y)
housing_price_classif_Y = housing_price_classif_Y

housing_price_X

# %% [markdown]
# # Fits Algorithms to datasets

# %%
data_chunks = [100, 500, 1000, 5000, 10000, 50000, 100000, 500000,
1000000, 5000000, 10000000, 50000000, 100000000]

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
def root_mean_square_error(y_actual, y_predicted):
    return sqrt(mean_squared_error(y_actual, y_predicted))

# %%
def model( X, y, dataset_name, algorithm): 
    
    algo_name = algorithm.__name__
    for chunk in data_chunks:
        
        # if chunk is greater than the no. of examples quite from the chunking
        if chunk > X.shape[0]: 
            chunk = X.shape[0]
        
        # generate the chunk file
        X = X[:, 0:chunk]
        y = y[:, 0:chunk]
        
        # fits algorithm to the dateset chunk
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
        lm = algorithm()
        model = lm.fit(X_train, y_train)
        
        # do the prediction
        predictions = model.predict(X_test)
        # Validate the prediction using mean square error        
        error = root_mean_square_error(y_test, predictions)  # RMSE https://www.kaggle.com/wiki/RootMeanSquaredError
        
        # print the result, we will need to have method that genereates the result csv file required.
        print ("Data set: {}\nAlgorithm: {}\nChunk Size: {}\nRMSE: {}".format(dataset_name,
                                                                          algo_name,
                                                                          chunk,
                                                                           error
                                                                         ))
        if chunk == X.shape[0]:
            break

# %%
def kFoldModel (X, y, dataset_name, kfolds, algorithm=LinearRegression):
    
    algo_name = algorithm.__name__
    
    kf = KFold(n_splits=kfolds)
    
    for train, test in kf.split(X, y):
        model(X,y, dataset_name, algorithm)

# %% [markdown]
# ## Fits Regression Algorithms to datasets
#
#     - Linear Regression
#     - Random Forest Regression

# %%
# kFoldModel(sumdata_noise_X, sumdata_noise_reg_Y, "The Sum Dataset(with noise)", 10, LinearRegression)
# kFoldModel(sumdata_X, sumdata_reg_Y, "The Sum Dataset(without noise)", 10,  LinearRegression )
kFoldModel(housing_price_X, housing_price_reg_Y, "Housing Dataset", 10, LinearRegression )

housing_price_X.shape
# kFoldModel(sumdata_noise_X, sumdata_noise_reg_Y,"The Sum Dataset(with noise)",10,  RandomForestRegressor )
# kFoldModel(sumdata_X, sumdata_reg_Y, "The Sum Dataset(with noise)",10,  RandomForestRegressor )
# kFoldModel(housing_price_X, housing_price_reg_Y, "The Sum Dataset(with noise)",10, RandomForestRegressor )
# Out:
# Data set: Housing Dataset
# Algorithm: LinearRegression
# Chunk Size: 100
# RMSE: 0.5199576276043364
# Data set: Housing Dataset
# Algorithm: LinearRegression
# Chunk Size: 500
# RMSE: 0.43896260638927687
# Data set: Housing Dataset
# Algorithm: LinearRegression
# Chunk Size: 1000
# RMSE: 0.7452794230502054
# Data set: Housing Dataset
# Algorithm: LinearRegression
# Chunk Size: 100
# RMSE: 0.43294755438782156
# Data set: Housing Dataset
# Algorithm: LinearRegression
# Chunk Size: 500
# RMSE: 0.5575951248008337
# Data set: Housing Dataset
# Algorithm: LinearRegression
# Chunk Size: 1000
# RMSE: 0.39681776175065553
# Data set: Housing Dataset
# Algorithm: LinearRegression
# Chunk Size: 100
# RMSE: 0.5624406968139155
# Data set: Housing Dataset
# Algorithm: LinearRegression
# Chunk Size: 500
# RMSE: 0.5676502554628778
# Data set: Housing Dataset
# Algorithm: LinearRegression
# Chunk Size: 1000
# RMSE: 0.49907245251138277
# Data set: Housing Dataset
# Algorithm: LinearRegression
# Chunk Size: 100
# RMSE: 0.3929855793545279
# Data set: Housing Dataset
# Algorithm: LinearRegression
# Chunk Size: 500
# RMSE: 0.5172388507643767
# Data set: Housing Dataset
# Algorithm: LinearRegression
# Chunk Size: 1000
# RMSE: 0.37176329273191877
# Data set: Housing Dataset
# Algorithm: LinearRegression
# Chunk Size: 100
# RMSE: 0.4386310154867048
# Data set: Housing Dataset
# Algorithm: LinearRegression
# Chunk Size: 500
# RMSE: 0.4853370609246949
# Data set: Housing Dataset
# Algorithm: LinearRegression
# Chunk Size: 1000
# RMSE: 0.47948372514644433
# Data set: Housing Dataset
# Algorithm: LinearRegression
# Chunk Size: 100
# RMSE: 0.4953540659286554
# Data set: Housing Dataset
# Algorithm: LinearRegression
# Chunk Size: 500
# RMSE: 0.5199775107124734
# Data set: Housing Dataset
# Algorithm: LinearRegression
# Chunk Size: 1000
# RMSE: 0.5670418442172545
# Data set: Housing Dataset
# Algorithm: LinearRegression
# Chunk Size: 100
# RMSE: 0.4403838952502776
# Data set: Housing Dataset
# Algorithm: LinearRegression
# Chunk Size: 500
# RMSE: 0.5617722193574407
# Data set: Housing Dataset
# Algorithm: LinearRegression
# Chunk Size: 1000
# RMSE: 0.3904615588075439
# Data set: Housing Dataset
# Algorithm: LinearRegression
# Chunk Size: 100
# RMSE: 0.4289188815919616
# Data set: Housing Dataset
# Algorithm: LinearRegression
# Chunk Size: 500
# RMSE: 0.5068346698905009
# Data set: Housing Dataset
# Algorithm: LinearRegression
# Chunk Size: 1000
# RMSE: 0.4364801895724063
# Data set: Housing Dataset
# Algorithm: LinearRegression
# Chunk Size: 100
# RMSE: 0.4653740112380026
# Data set: Housing Dataset
# Algorithm: LinearRegression
# Chunk Size: 500
# RMSE: 0.4828330320981973
# Data set: Housing Dataset
# Algorithm: LinearRegression
# Chunk Size: 1000
# RMSE: 0.42987871374469244
# Data set: Housing Dataset
# Algorithm: LinearRegression
# Chunk Size: 100
# RMSE: 0.6209109518293117
# Data set: Housing Dataset
# Algorithm: LinearRegression
# Chunk Size: 500
# RMSE: 0.4995941078262383
# Data set: Housing Dataset
# Algorithm: LinearRegression
# Chunk Size: 1000
# RMSE: 0.5321287322484597
# (1460, 37)
